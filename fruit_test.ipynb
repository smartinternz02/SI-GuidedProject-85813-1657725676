# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array

# %%
model=load_model("fruit.h5")

# %%
img=image.load_img(r'apple-black.jpg',target_size=(128,128))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x20D103EADC0>

# %%
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)

# %%
pred=model.predict_classes(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14924/143353793.py in <module>
# ----> 1 pred=model.predict_classes(x)
#
# AttributeError: 'Sequential' object has no attribute 'predict_classes'

# %%
pred=np.argmax(model.predict(x),axis=1)
# Out:
# 1/1 [==============================] - 0s 325ms/step

# %%
pred
# Out:
# array([1], dtype=int64)
